# %%
from dask.distributed import Client, Scheduler, Nanny, SpecCluster
from dask_cuda.worker_spec import worker_spec
import dask
import psutil
import multiprocessing

# %%
# gather device info
cpu_count = multiprocessing.cpu_count()
memory_count = psutil.virtual_memory().total
print("CPU count:", cpu_count)
print("System memory:",memory_count)
# Out:
# CPU count: 16
# System memory: 134746021888

# %%
specs = {
    "cpu":{
        "scale":3,
        "resources":{
        }
    },
    "gpu":{
        "scale":1,
        "resources":{
            "CUDA_VISIBLE_DEVICES": [0],
        }
    }
}

worker_count = 0
for v in specs.values():
    worker_count += v["scale"]

nthreads = cpu_count//worker_count
memory_limit = int(memory_count*0.9)//worker_count # set to use 90% of the system memory to avoid crashing

print("number of workers:", worker_count)
print("threads per worker:", nthreads)
print("memory limit per worker:", round(memory_limit/(1024*1024*1024),2), "GB")
# Out:
# number of workers: 4
# threads per worker: 4
# memory limit per worker: 28.24 GB

# %%
worker_spec(threads_per_worker=nthreads, memory_limit=memory_limit, CUDA_VISIBLE_DEVICES=[0])
# Out:
# {0: {'cls': distributed.nanny.Nanny,
#   'options': {'env': {'CUDA_VISIBLE_DEVICES': '0'},
#    'interface': None,
#    'protocol': None,
#    'nthreads': 4,
#    'data': dict,
#    'dashboard_address': ':8787',
#    'plugins': [<dask_cuda.utils.CPUAffinity at 0x7efcd9eefd00>],
#    'silence_logs': True,
#    'memory_limit': 134746021888.0,
#    'preload': 'dask_cuda.initialize',
#    'preload_argv': '--create-cuda-context'}}}

# %%
workers = {}

for k, v in specs.items():
    for i in range(v["scale"]):
        if "CUDA_VISIBLE_DEVICES" in v["resources"].keys():
            workers["{}-{}".format(k,i)] = worker_spec(
                threads_per_worker=nthreads, 
                CUDA_VISIBLE_DEVICES=v["resources"]["CUDA_VISIBLE_DEVICES"]
                )[0]
            workers["{}-{}".format(k,i)]["options"]["resources"]={"GPU":len(v["resources"]["CUDA_VISIBLE_DEVICES"])}
            workers["{}-{}".format(k,i)]["options"]["memory_limit"]=memory_limit
        else:
            workers["{}-{}".format(k,i)] = {
                "cls":Nanny,
                "options":{
                    "nthreads": nthreads,
                    "memory_limit": memory_limit
                    }
             }     
            
workers
# Out:
# {'cpu-0': {'cls': distributed.nanny.Nanny,
#   'options': {'nthreads': 4, 'memory_limit': 30317854924}},
#  'cpu-1': {'cls': distributed.nanny.Nanny,
#   'options': {'nthreads': 4, 'memory_limit': 30317854924}},
#  'cpu-2': {'cls': distributed.nanny.Nanny,
#   'options': {'nthreads': 4, 'memory_limit': 30317854924}},
#  'gpu-0': {'cls': distributed.nanny.Nanny,
#   'options': {'env': {'CUDA_VISIBLE_DEVICES': '0'},
#    'interface': None,
#    'protocol': None,
#    'nthreads': 4,
#    'data': dict,
#    'dashboard_address': ':8787',
#    'plugins': [<dask_cuda.utils.CPUAffinity at 0x7efbb0b83430>],
#    'silence_logs': True,
#    'memory_limit': 30317854924,
#    'preload': 'dask_cuda.initialize',
#    'preload_argv': '--create-cuda-context',
#    'resources': {'GPU': 1}}}}

# %%
scheduler = {'cls': Scheduler, 'options': {"dashboard_address": ':8787'}}
cluster = SpecCluster(scheduler=scheduler, workers=workers)
client = Client(cluster)
client
# Out:
# 2023-04-14 16:45:40,874 - distributed.http.proxy - INFO - To route to workers diagnostics web server please install jupyter-server-proxy: python -m pip install jupyter-server-proxy
# /home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36279 instead
#   warnings.warn(
# 2023-04-14 16:45:40,899 - distributed.scheduler - INFO - State start
# 2023-04-14 16:45:40,904 - distributed.scheduler - INFO -   Scheduler at: tcp://129.67.90.167:33471
# 2023-04-14 16:45:40,904 - distributed.scheduler - INFO -   dashboard at:                    :36279
# 2023-04-14 16:45:40,940 - distributed.nanny - INFO -         Start Nanny at: 'tcp://129.67.90.167:41083'
# 2023-04-14 16:45:40,944 - distributed.nanny - INFO -         Start Nanny at: 'tcp://129.67.90.167:35539'
# 2023-04-14 16:45:40,948 - distributed.nanny - INFO -         Start Nanny at: 'tcp://129.67.90.167:44937'
# 2023-04-14 16:45:40,953 - distributed.nanny - INFO -         Start Nanny at: 'tcp://129.67.90.167:46533'
# 2023-04-14 16:45:41,232 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-213e7dqj', purging
# 2023-04-14 16:45:41,234 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-hv3ry6en', purging
# 2023-04-14 16:45:41,234 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-2z5la8b_', purging
# 2023-04-14 16:45:41,234 - distributed.diskutils - INFO - Found stale lock file and directory '/tmp/dask-worker-space/worker-f0wbz3ku', purging
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -       Start worker at:  tcp://129.67.90.167:35529
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -          Listening to:  tcp://129.67.90.167:35529
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -           Worker name:                      cpu-2
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -          dashboard at:        129.67.90.167:45219
# 2023-04-14 16:45:41,258 - distributed.worker - INFO - Waiting to connect to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,258 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -               Threads:                          4
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -                Memory:                  28.24 GiB
# 2023-04-14 16:45:41,258 - distributed.worker - INFO -       Local Directory: /tmp/dask-worker-space/worker-2r7n29wp
# 2023-04-14 16:45:41,258 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -       Start worker at:  tcp://129.67.90.167:34405
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -          Listening to:  tcp://129.67.90.167:34405
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -           Worker name:                      cpu-1
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -          dashboard at:        129.67.90.167:38589
# 2023-04-14 16:45:41,266 - distributed.worker - INFO - Waiting to connect to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,266 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -               Threads:                          4
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -                Memory:                  28.24 GiB
# 2023-04-14 16:45:41,266 - distributed.worker - INFO -       Local Directory: /tmp/dask-worker-space/worker-c5t470dt
# 2023-04-14 16:45:41,266 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -       Start worker at:  tcp://129.67.90.167:44155
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -          Listening to:  tcp://129.67.90.167:44155
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -           Worker name:                      cpu-0
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -          dashboard at:        129.67.90.167:36805
# 2023-04-14 16:45:41,272 - distributed.worker - INFO - Waiting to connect to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,272 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -               Threads:                          4
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -                Memory:                  28.24 GiB
# 2023-04-14 16:45:41,272 - distributed.worker - INFO -       Local Directory: /tmp/dask-worker-space/worker-ga9mfvx4
# 2023-04-14 16:45:41,273 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,459 - distributed.scheduler - INFO - Register worker <WorkerState 'tcp://129.67.90.167:34405', name: cpu-1, status: init, memory: 0, processing: 0>
# 2023-04-14 16:45:41,463 - distributed.scheduler - INFO - Starting worker compute stream, tcp://129.67.90.167:34405
# 2023-04-14 16:45:41,463 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:56216
# 2023-04-14 16:45:41,463 - distributed.worker - INFO -         Registered to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,463 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,464 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,471 - distributed.scheduler - INFO - Register worker <WorkerState 'tcp://129.67.90.167:44155', name: cpu-0, status: init, memory: 0, processing: 0>
# 2023-04-14 16:45:41,472 - distributed.scheduler - INFO - Starting worker compute stream, tcp://129.67.90.167:44155
# 2023-04-14 16:45:41,472 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:56230
# 2023-04-14 16:45:41,473 - distributed.worker - INFO -         Registered to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,473 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,474 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,492 - distributed.scheduler - INFO - Register worker <WorkerState 'tcp://129.67.90.167:35529', name: cpu-2, status: init, memory: 0, processing: 0>
# 2023-04-14 16:45:41,493 - distributed.scheduler - INFO - Starting worker compute stream, tcp://129.67.90.167:35529
# 2023-04-14 16:45:41,494 - distributed.worker - INFO -         Registered to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,494 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:56208
# 2023-04-14 16:45:41,494 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,495 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,787 - distributed.preloading - INFO - Creating preload: dask_cuda.initialize
# 2023-04-14 16:45:41,787 - distributed.preloading - INFO - Import preload module: dask_cuda.initialize
# /home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36451 instead
#   warnings.warn(
# 2023-04-14 16:45:41,808 - distributed.preloading - INFO - Run preload setup: dask_cuda.initialize
# 2023-04-14 16:45:41,808 - distributed.worker - ERROR - Failed to start preload
# Traceback (most recent call last):
#   File "/home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/distributed/worker.py", line 1402, in start_unsafe
#     await preload.start()
#   File "/home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/distributed/preloading.py", line 202, in start
#     context = dask_setup.make_context(
#   File "/home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/click/core.py", line 920, in make_context
#     self.parse_args(ctx, args)
#   File "/home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/click/core.py", line 1381, in parse_args
#     ctx.fail(
#   File "/home/jackyko/mambaforge/envs/myocardial/lib/python3.10/site-packages/click/core.py", line 679, in fail
#     raise UsageError(message, self)
# click.exceptions.UsageError: Got unexpected extra arguments (- - c r e a t e - c u d a - c o n t e x t)
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -       Start worker at:  tcp://129.67.90.167:41215
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -          Listening to:  tcp://129.67.90.167:41215
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -           Worker name:                      gpu-0
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -          dashboard at:        129.67.90.167:36451
# 2023-04-14 16:45:41,810 - distributed.worker - INFO - Waiting to connect to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,810 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -               Threads:                          4
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -                Memory:                  28.24 GiB
# 2023-04-14 16:45:41,810 - distributed.worker - INFO -       Local Directory: /tmp/dask-worker-space/worker-_onhnia6
# 2023-04-14 16:45:41,810 - distributed.worker - INFO - Starting Worker plugin CPUAffinity-77b24289-a160-4aa5-b085-765c1f55e1ef
# 2023-04-14 16:45:41,810 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,817 - distributed.scheduler - INFO - Register worker <WorkerState 'tcp://129.67.90.167:41215', name: gpu-0, status: init, memory: 0, processing: 0>
# 2023-04-14 16:45:41,818 - distributed.scheduler - INFO - Starting worker compute stream, tcp://129.67.90.167:41215
# 2023-04-14 16:45:41,818 - distributed.worker - INFO -         Registered to:  tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,819 - distributed.worker - INFO - -------------------------------------------------
# 2023-04-14 16:45:41,819 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:33471
# 2023-04-14 16:45:41,820 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:56238
# 2023-04-14 16:45:41,829 - distributed.scheduler - INFO - Receive client connection: Client-6955901d-dadb-11ed-b452-b07b25216e2e
# 2023-04-14 16:45:41,830 - distributed.core - INFO - Starting established connection to tcp://129.67.90.167:56244
# <Client: 'tcp://129.67.90.167:33471' processes=4 threads=16, memory=112.94 GiB>

# %%
client.cluster.workers
# Out:
# {'gpu-0': <Nanny: tcp://129.67.90.167:41215, threads: 4>,
#  'cpu-0': <Nanny: tcp://129.67.90.167:44155, threads: 4>,
#  'cpu-2': <Nanny: tcp://129.67.90.167:35529, threads: 4>,
#  'cpu-1': <Nanny: tcp://129.67.90.167:34405, threads: 4>}

# %%
def inc(x):
    return x + 1

# %%
x= dask.delayed(inc)(1)

# %%
# specify the worker for the compute process
with dask.annotate(resources={'GPU': 1}):
    res = dask.compute(x)
